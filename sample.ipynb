# %%
from google import genai

# The client gets the API key from the environment variable `GEMINI_API_KEY`.
client = genai.Client()

response = client.models.generate_content(
    model="gemini-2.5-flash-lite", contents="Explain how AI works in a few words"
)
print(response.text)
# Out:
# AI learns from data to make predictions or decisions.

# %%
"""Example of reannotating the WildChat dataset using curator."""

import logging
from bespokelabs import curator

# To see more detail about how batches are being processed
logger = logging.getLogger("bespokelabs.curator")
logger.setLevel(logging.INFO)


class WildChatReannotator(curator.LLM):
    """A reannotator for the WildChat dataset."""

    def prompt(self, input: dict) -> str:
        """Extract the first message from a conversation to use as the prompt."""
        return input["conversation"][0]["content"]

    def parse(self, input: dict, response: str) -> dict:
        """Parse the model response along with the input to the model into the desired output format.."""
        instruction = input["conversation"][0]["content"]
        return {"instruction": instruction, "new_response": response}
# Out:
# /home/shreyas/NLP/SM/gensemworkspaces/gsw-memory/.venv/lib/python3.10/site-packages/torch/cuda/__init__.py:789: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")

# %%
distiller = WildChatReannotator(model_name="gemini-1.5-flash-002", 
                                backend="gemini", 
                                batch=True 
                                )
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 distiller = WildChatReannotator(model_name="gemini-1.5-flash-002",
#       2                                 backend="gemini",
#       3                                 batch=True
#       4                                 )
#
# File ~/NLP/SM/gensemworkspaces/gsw-memory/.venv/lib/python3.10/site-packages/bespokelabs/curator/llm/llm.py:136, in LLM.__init__(self, model_name, response_format, batch, backend, generation_params, backend_params, system_prompt)
#     126 self.prompt_formatter = PromptFormatter(
#     127     model_name=model_name,
#     128     prompt_func=self.prompt,
#    (...)
#     132     system_prompt=system_prompt,
#     133 )
#     134 self.batch_mode = batch
# --> 136 self._request_processor = _RequestProcessorFactory.create(
#     137     params=backend_params,
#     138     model_name=model_name,
#     139     batch=batch,
#     140     response_format=response_format,
#     141     backend=backend,
#     142     generation_params=generation_params,
#     143     return_completions_object=self.return_completions_object,
#     144 )
#
# File ~/NLP/SM/gensemworkspaces/gsw-memory/.venv/lib/python3.10/site-packages/bespokelabs/curator/request_processor/_factory.py:155, in _RequestProcessorFactory.create(cls, model_name, params, generation_params, batch, backend, response_format, return_completions_object)
#     152 if backend == "gemini" and batch:
#     153     from bespokelabs.curator.request_processor.batch.gemini_batch_request_processor import GeminiBatchRequestProcessor
# --> 155     return GeminiBatchRequestProcessor(config)
#     157 if backend == "anthropic" and not batch:
#     158     from bespokelabs.curator.request_processor.online.anthropic_online_request_processor import AnthropicOnlineRequestProcessor
#
# File ~/NLP/SM/gensemworkspaces/gsw-memory/.venv/lib/python3.10/site-packages/bespokelabs/curator/request_processor/batch/gemini_batch_request_processor.py:89, in GeminiBatchRequestProcessor.__init__(self, config)
#      87 """Initialize the GeminiBatchRequestProcessor."""
#      88 super().__init__(config)
# ---> 89 self._initialize_cloud()
#
# File ~/NLP/SM/gensemworkspaces/gsw-memory/.venv/lib/python3.10/site-packages/bespokelabs/curator/request_processor/batch/gemini_batch_request_processor.py:96, in GeminiBatchRequestProcessor._initialize_cloud(self)
#      93 self._project_id = os.environ.get("GOOGLE_CLOUD_PROJECT")
#      94 self._bucket_name = os.environ.get("GEMINI_BUCKET_NAME")
# ---> 96 assert self._bucket_name, "GEMINI_BUCKET_NAME environment variable is not set"
#      97 assert self._project_id is not None, "GOOGLE_CLOUD_PROJECT environment variable is not set"
#      98 assert self._location is not None, "GOOGLE_CLOUD_REGION environment variable is not set"
#
# AssertionError: GEMINI_BUCKET_NAME environment variable is not set
